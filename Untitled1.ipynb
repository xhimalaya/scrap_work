# %%
import bezier
import numpy as np
from bezier import surface as sr
import matplotlib.pyplot as plt
from SW import manuscript
#===================================================================
fig = plt.figure(figsize=[2,2])
inp= input("Enter Char : ")
x,y= manuscript.return_manuscript_fonts(inp)
ax= plt.axes()
if isinstance(x[0],list):
    for i in range(len(x)):
        nodes = np.asarray([x[i],y[i]],dtype=np.double)
        curve = bezier.Curve(nodes, degree=2)
        curve.plot(num_pts=100,ax=ax)
    plt.show()
else:
    nodes = np.asarray([x,y],dtype=np.double)
    curve = bezier.Curve(nodes, degree=2)
    curve.plot(num_pts=100,ax=ax)
plt.show()
# Out:
# Enter Char : R

# %%
import bezier
import numpy as np
from bezier import surface as sr
import matplotlib.pyplot as plt
from SW import manuscript
def ang(x1x,x1y,x2x,x2y,x3x,x3y):
        global q
        a=np.array([x1x,x1y])
        b=np.array([x2x,x2y])
        c=np.array([x3x,x3y])
        ba = a - b
        bc = c - b
        cosine_angle = np.dot(ba, bc) / (np.linalg.norm(ba) * np.linalg.norm(bc))
        angle = np.arccos(cosine_angle)
        return np.degrees(angle)
#===================================================================
fig = plt.figure(figsize=[2,2])
inp= input("Enter Char : ")
x,y= manuscript.return_manuscript_fonts(inp)
ax= plt.axes()
if isinstance(x[0],list):
    for i in range(len(x)-2):
        if ang(x[i],y[i],x[i+1],y[i+1],x[i+2],y[i+2])>90.0:
            nodes = np.asarray([x[i],y[i]],dtype=np.double)
            curve = bezier.Curve(nodes, degree=2)
            curve.plot(num_pts=100,ax=ax)
        else:
            plt.plot([x[i],x[i+1],x[i+2]],[y[i],y[i+1],y[i+2]])
    plt.show()
else:
    nodes = np.asarray([x,y],dtype=np.double)
    curve = bezier.Curve(nodes, degree=2)
    curve.plot(num_pts=100,ax=ax)
plt.show()
# Out:
# Enter Char : S

# %%
def test(z):    
    import bezier
    import numpy as np
    from bezier import surface as sr
    import matplotlib.pyplot as plt
    from SW import manuscript
    #===================================================================
    try:
        fig = plt.figure(figsize=[2,2])
        #inp= input("Enter Char : ")
        x,y= manuscript.return_manuscript_fonts(z)
        ax= plt.axes()
        if isinstance(x[0],list):
            for i in range(len(x)):
                nodes = np.asarray([x[i],y[i]],dtype=np.double)
                curve = bezier.Curve(nodes, degree=2)
                curve.plot(num_pts=100,ax=ax)
        else:
            nodes = np.asarray([x,y],dtype=np.double)
            curve = bezier.Curve(nodes, degree=2)
            curve.plot(num_pts=100,ax=ax)
        er="right input ",z
        plt.title(er)
        plt.show()
    except Exception as e:
        print("Wrong input ",e," and exception is ",z1)

# %%
import matplotlib.pyplot as plt
def angle(x,y):
    def ang(x1x,x1y,x2x,x2y,x3x,x3y):
        global q
        a=np.array([x1x,x1y])
        b=np.array([x2x,x2y])
        c=np.array([x3x,x3y])
        ba = a - b
        bc = c - b
        cosine_angle = np.dot(ba, bc) / (np.linalg.norm(ba) * np.linalg.norm(bc))
        angle = np.arccos(cosine_angle)
        print(np.degrees(angle))
        return({np.degrees(angle):{'x':[x1x,x2x,x3x],"y":[x1y,x2y,x3y]}})
    x1x=[]
    x1y=[]
    x2x=[]
    x2y=[]
    i=0
    lnt=len(x)
    while True:
        if i==(lnt+1):
            break
        else:
            if len(x[i])<3:
                plt.plot(x[i],y[i],"or")
            else:
                try:
                    pt1x=x[i]
                    pt1y=y[i]
                    pt2x=x[i+1]
                    pt2y=y[i+1]
                    pt3x=x[i+2]
                    pt3y=y[i+2]
                    print(ang(pt1x,pt1y,pt2x,pt2y,pt3x,pt3y))
                except Exception as e:
                    print(e)
            i=i+2
            
            #z= ang(pt1x,pt1y,pt2x,pt2y,pt3x,pt3y)
            '''if z<=90.0: 
                print(z)
                print(pt1x,pt1y,"\n",pt2x,pt2y,"\n",pt3x,pt3y)
                x1x.append(pt1x)
                x1x.append(pt2x)
                x1x.append(pt3x)
                x1y.append(pt1y)
                x1y.append(pt2y)
                x1y.append(pt3y)
            else:
                x2x.append(pt1x)
                x2x.append(pt2x)
                x2x.append(pt3x)
                x2y.append(pt1y)
                x2y.append(pt2y)
                x2y.append(pt3y)'''
            i+=1
    print(x1x,x1y,x2x,x2y)
from SW import manuscript
vb=input("enter the charecter: ")
x,y= manuscript.return_manuscript_fonts(vb)
angle(x,y)
# Out:
# enter the charecter: g
# list index out of range
# [] [] [] []

# %%
from SW import manuscript
for vb in range(256):
    x,y= manuscript.return_manuscript_fonts(chr(vb))
    if len(x)==0 and len(y)==0:
        pass
    else:
        if isinstance(x[0],list):
            for i in range(len(x)):
                if len(x[i])
                if len(x[i])%3==0 or len(x[i])%3==0.0:
                    print(str(chr(vb))," is good")
                else:
                    print(str(chr(vb))," is bad")
        else:
            if len(x)%3==0 or len(x)%3==0.0:
                print(str(chr(vb))," is good")
            else:
                print(str(chr(vb))," is bad")
# Out:
# !  is bad
# !  is good
# !  is good
# !  is good
# !  is good
# !  is good
# !  is good
# !  is good
# !  is good
# "  is bad
# "  is bad
# #  is bad
# #  is bad
# #  is bad
# #  is bad
# $  is bad
# $  is good
# %  is bad
# %  is bad
# %  is bad
# &  is bad
# '  is good
# (  is bad
# )  is bad
# *  is bad
# *  is bad
# *  is bad
# *  is bad
# +  is bad
# +  is bad
# ,  is good
# ,  is good
# ,  is good
# ,  is good
# ,  is bad
# ,  is good
# ,  is good
# -  is bad
# .  is good
# .  is good
# .  is good
# .  is good
# .  is good
# .  is good
# .  is good
# .  is good
# /  is bad
# 0  is bad
# 1  is bad
# 2  is bad
# 3  is bad
# 4  is bad
# 4  is good
# 5  is good
# 6  is bad
# 7  is good
# 8  is bad
# 9  is bad
# 9  is bad
# 9  is bad
# 9  is bad
# 9  is bad
# :  is good
# :  is good
# :  is good
# :  is good
# :  is good
# :  is good
# :  is good
# :  is good
# :  is good
# :  is good
# :  is good
# :  is good
# :  is good
# :  is good
# :  is good
# :  is good
# ;  is good
# ...
